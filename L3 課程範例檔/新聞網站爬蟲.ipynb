# %%
# -*- coding: utf-8 -*-
import requests
from bs4 import BeautifulSoup
import re


new_list = []
url = 'https://money.udn.com/money/index'

## 1.填寫headers
headers = {
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')
div = soup.find('div', {'id': 'tab1'})
a_tags = div.find_all('a')
## 2.抓取即時區域所有新聞title以及新聞內容連結link，並將每篇新聞的連結link append到new_list內

for i in a_tags:
    print('title: {}, link: {}'.format(i.text, 'https://money.udn.com'+i['href']))
    new_list.append('https://money.udn.com'+i['href'])
# Out:
# title: 12:38港721元朗襲擊案 7名白衣施襲者被判刑, link: https://money.udn.com/money/story/5603/5619319?from=edn_breaknewstab_index
# title: 12:38香港蘋果日報4高層被控違國安法  9月再訊, link: https://money.udn.com/money/story/5603/5619324?from=edn_breaknewstab_index
# title: 12:38颱風烟花影響降雨持續  新竹累積雨量達199毫米, link: https://money.udn.com/money/story/5621/5619322?from=edn_breaknewstab_index
# title: 12:37美軍最高將領：阿富汗半數區域中心遭塔利班掌控, link: https://money.udn.com/money/story/5599/5619323?from=edn_breaknewstab_index
# title: 12:37英業達：第3季是訂單需求高點 視缺料情況調整產能, link: https://money.udn.com/money/story/5612/5619320?from=edn_breaknewstab_index
# title: 12:37政院宣布：昨已簽約增購3600萬劑莫德納疫苗, link: https://money.udn.com/money/story/5658/5619283?from=edn_breaknewstab_index
# title: 12:35陳寶郎斷言下半年油價：怎麼看都認為會上漲, link: https://money.udn.com/money/story/5618/5619315?from=edn_breaknewstab_index
# title: 12:35盼降級！ 調查：三級警戒影響企業營運平均5~6個月, link: https://money.udn.com/money/story/5617/5619316?from=edn_breaknewstab_index
# title: 12:32搶翻了！六都土地交易5年翻2倍 規模逼近兆元, link: https://money.udn.com/money/story/5621/5619304?from=edn_breaknewstab_index

# %%
from time import sleep
import os
from bs4 import BeautifulSoup
from urllib.request import urlretrieve

def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print ('Error: Creating directory. ' +  directory)

        
def save_news(url):
    
    ## 3.填寫headers
    headers = {
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
    }
    response = requests.get(url, headers=headers)
    sleep(1)
    
    soup = BeautifulSoup(response.text, 'html.parser')
    ## 4. 使用find_all去抓取每篇新聞的title(指定是哪個tag以及指定id)，將結果所產生之list放到new_title變數內
    new_title = soup.find_all('h2',{'id': 'story_art_title'})
    
    save_path = './news/'+new_title[0].text.replace(':','')
    
    article_body = soup.find_all('div',{'id':'article_body'})
    print('new title: {}'.format(new_title[0].text))

    ## create folder
    createFolder(save_path)
    soup2 = BeautifulSoup(str(article_body[0]), 'html.parser')


    ## save article contens in folder
    p_tags = soup2.find_all('p')
    with open(save_path+'/contents.txt', 'w', encoding='utf-8') as f:  
        ## 5. 抓取文章內p tags，並將新聞內文寫入contents.txt檔案內
        print('new content: ')
        for i in p_tags:
            print(i.text)
            f.write(i.text)

    ## save image in article        
    
    ## 6. 抓取文章內所有img tags，並將圖片下載並存入對應新聞資料夾下
    img_tags = soup2.find_all('img')
    print('save image: ')
    for i in img_tags:
        print(i['src'])
        urlretrieve(i['src'], save_path+'/'+i['title']+'.jpg')
    print('==========\n\n')
    

for new_url in new_list:
    print(new_url)
    save_news(new_url)
# Out:
# https://money.udn.com/money/story/5603/5619319?from=edn_breaknewstab_index
# new title: 港721元朗襲擊案 7名白衣施襲者被判刑
# new content:
# 香港「反送中」運動示威者前年7月21日在新界元朗遭人暴打，事件觸發更大規模示威；7名參與暴打示威者的人今天被法院各被判囚3年半至7年不等。
#
# 商業電台報導，7名被告被裁定參與暴動罪及有意圖傷害他人罪名成立，區域法院今早就此宣判。
#
# 前年7月21日，大批「反送中」示威者響應呼籲，到元朗集會遊行，期間曾與當地居民發生衝突。當晚，正當示威者搭乘元朗地鐵離開時，大批穿白衣的人突然進入地鐵站以木棍等物件襲擊示威者。
#
# 這次襲擊激發更多「反送中」支持者上街遊行示威，他們並把矛頭指向警方，聲稱襲擊當晚，示威者曾報警求救，但警方卻遲遲不派人處理，質疑警方「縱容白衣人毆打示威者」。
#
# 「721」事件後，警方逮捕了一批攻擊「反送中」示威者的白衣人，依暴動罪和意圖傷害他人罪起訴他們，但也逮捕了一批示威者，同樣起訴他們參與暴動罪。
#
# 「721」事件發生後，有穿白衣的襲擊者向媒體聲稱，他們是要保衛家園，且是先受到穿黑衣示威者襲擊，才作出反擊。
#
# 這是本地法院首次就「721」事件判刑。
# save image:
# ==========
#
#
# https://money.udn.com/money/story/5603/5619324?from=edn_breaknewstab_index
# new title: 香港蘋果日報4高層被控違國安法  9月再訊
# new content:
# 香港前蘋果日報4名高層包括副社長陳沛敏被當局依港區國安法拘補和起訴，4人今早出庭，法官延後案件至9月30日審訊。
#
# 綜合本地媒體的報導，4名被告陳沛敏、執行總編輯林文宗、主筆馮偉光和楊清奇，今早在西九龍裁判法院出庭，法官拒絕4人保釋，延後聆訊。
#
# 陳沛敏等人自上月6月中起先後被警方拘捕，而警方此前也逮捕了蘋果日報母公司壹傳媒集團創辦人黎智英等多名高層，指他們涉嫌違反國安法中的「串謀勾結外國或者境外勢力危害國家安全罪」。
# save image:
# ==========
#
#
# https://money.udn.com/money/story/5621/5619322?from=edn_breaknewstab_index
# new title:
# new content:
#
# save image:
# ==========
#
#
# https://money.udn.com/money/story/5599/5619323?from=edn_breaknewstab_index
# new title: 美軍最高將領：阿富汗半數區域中心遭塔利班掌控
# new content:
# 美軍參謀首長聯席會議主席密利（Mark Milley）今天表示，阿富汗目前約有半數的區域中心落入叛亂分子塔利班（Taliban）手中，表示阿富汗國內安全局勢正在急劇惡化。
#
# 路透社報導，阿富汗近幾週來不安全的情勢日益加劇，主要是受到境內各省戰事四起所致；美國為首的外國部隊正全面撤離阿富汗，塔利班伺機發動大規模攻勢，陸續拿下各區和邊界過境點。
#
# 陸軍上將密利向媒體表示：「戰略勢頭似乎算是在塔利班那一方。」
#
# 密利上個月曾表示塔利班拿下阿富汗境內81個區域中心，如今他指出，阿富汗419個區域中心裡，目前有超過200個都在塔利班掌控下。
#
# 密利指出，雖然塔利班目前尚未拿下任何省會，但正步步逼近半數省會的邊郊，不過他也表示，要說塔利班取得勝利，還言之過早。
#
# 他表示，阿富汗部隊「正在鞏固兵力」以保護大型城市中心：「他們正在採取一種方法來保護人民，且多數人口都住在省會和首都喀布爾（Kabul）。塔利班自動軍事接管並非已成定局。」
#
# 塔利班的成功考驗著阿富汗軍隊的士氣。阿富汗軍隊多年來死傷人數高得嚇人．最近國際部隊決定撤出阿富汗，更讓政府軍士氣大受打擊。
#
# 雖然阿富汗軍隊接受國際部隊的訓練和裝備，且人數估計大大超越塔利班，密利仍表示，要打贏勝仗並非單靠以眾擊寡就能做到。
#
# 他說：「最重要的2個戰鬥乘數其實是意志和領導能力。如今這會是對阿富汗人民、阿富汗維安部隊和阿富汗政府的一場意志與領導能力的考驗。」
# save image:
# ==========
#
#
# https://money.udn.com/money/story/5612/5619320?from=edn_breaknewstab_index
# new title: 英業達：第3季是訂單需求高點 視缺料情況調整產能
# new content:
# 筆電代工廠英業達今天召開股東常會，會中通過配發現金股利每股新台幣1.85元，下半年仍需觀察缺料狀況，隨時動態調整產能因應出貨需求。
#
# 英業達今天股東會除承認2020年度財務報表及盈餘分配表外，並通過董事選舉辦法部分條文及股東會議事規則部分條文的修訂，會議進行約30分鐘結束。
#
# 英業達2021年上半年合併營收約新台幣2266.52億元，年減4.54%。英業達表示，今年上半年筆電與伺服器受惠宅經濟及新平台轉換需求續強，但產業供應鏈缺料，導致無法滿足需求端的出貨；第3季整體仍是今年訂單需求的高點，下半年仍需觀察缺料狀況，隨時動態調整產能因應出貨需求。
#
# 展望今年，英業達主要著眼於3大面向。首先，伺服器業務因新平台轉換及大型資料中心客戶成長力道挹注，今年營運展望可期，然而受到缺料影響，下半年仍需觀察料況隨時調整出貨動能。
#
# 其次，英業達筆電受惠於宅經濟與平台轉換今年仍延續出貨熱潮，供應鏈缺料雖限制部分出貨規格，但期待下半年出貨可以較有彈性，滿足客戶需求。
#
# 此外，英業達智慧裝置因產品推陳出新、下半年市場需求回溫，營運較前一年度看好，但缺料影響是整個電子業的綜合反應，出貨仍需視料況滾動式調整。
#
# 新事業布局方面，今年中開始台灣微軟攜手英業達啟動Inventec 5G Smart Factory IoT平台建置計畫，打造全新5G智慧工廠架構，透過微軟旗下以虛擬化運作的雲原生網路解決方案Affirmed Networks，開啟雙方戰略合作，未來也可以整廠輸出5G智慧工廠給其他的製造工廠。
#
# 英業達表示，公司也積極開發車用電子產品，以達到智能車載水準；醫療產品希望達到全面的健康智慧照護；同時透過數位轉型來重新定義商業模式、調整組織架構，並設定績效目標及優化營運指標，聚焦研發產品的組合效益分析，提高產品獲利能見度。
# save image:
# ==========
#
#
# https://money.udn.com/money/story/5658/5619283?from=edn_breaknewstab_index
# new title: 政院宣布：昨已簽約增購3600萬劑莫德納疫苗
# new content:
# 行政院昨公布與慈濟基金會完成簽署德國BNT疫苗的捐贈契約，也透露今年第四季，和明、後年將增購莫德納疫苗。行政院發言人羅秉成今表示，行政院已在昨日完成簽約，將購入3600萬劑莫德納疫苗。
#
#
#
# 羅秉成今在行政院會會後記者會中表示，昨日除了慈濟專案已經簽約完成外，政府也積極在進行國際疫苗的採購，其中莫德納疫苗已經在進行相關規劃，包括第四季的增加採購，乃至明、後年的預為採購，共為3600萬劑，也在昨天完成相關簽約手續。
#
#
#
# 至於何時到貨，羅秉成表示，時程的安排，乃至價格，因有保密協定的關係，暫時不予說明，但政府將爭取按照預排的時間來供貨。
#
#
#
# 羅秉成說，大致上這3600萬劑的莫德納疫苗，台灣希望能夠包括次世代的疫苗在內，而這樣的數量比原先預期的3000萬劑還多一些，爾後供貨情形，及後續的施打狀況，要看之後疫苗到貨的時間而定。
#
#
#
# 契約是否有保證交貨期程？羅秉成說，國際上疫苗短缺，大家都在爭取，供貨吃緊。保證要付高度法律責任與風險，疫苗是賣方市場，在賣方確保自己履約不受違約風險究責，不會答應確定時程交貨，大多數買方都要配合，也就是沒有保證供貨期程，這是國際慣例，都是預排時程但不保證。本報資料照片facebook
# save image:
# https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/22/realtime/13101601.png&x=0&y=0&sw=0&sh=0&sl=W&fw=1050&exp=3600&exp=3600
# ==========
#
#
# https://money.udn.com/money/story/5618/5619315?from=edn_breaknewstab_index
# new title: 陳寶郎斷言下半年油價：怎麼看都認為會上漲
# new content:
# 台塑化（6505）今天舉行股東會，面對外界最關心的下半年油價走勢，台塑化董事長陳寶郎鐵口直斷，認為下半年原油供需缺口浮現，怎麼看，我都認為油價會上漲，他估計第3季布蘭特油價有機會挑戰每桶80美元大關。這將有利台塑化下半年營運。
#
#
#
# 陳寶郎說，隨著各國疫情趨緩及陸續解封，經濟活動有了逐步復甦的跡象，帶動原油和各項石化品價格上漲，今年台塑化整體經營環境已大幅改善。
#
#
#
# 展望下半年，上周OPEC+（石油輸出國組織）達成增產協議，加上Delta變種病毒肆虐，造成杜拜原油價格掉下來，一度掉到每桶68.6美元，一口氣掉了5%，這個是非常嚴重。但依我的看法，怎麼看都覺得第3季油價會往上拉。
#
#
#
# 因為看油價必須同時看需求面和供應面，現在因為歐美疫苗施打覆蓋率到一定程度，政府比較敢把經濟活動放寬，車子、人敢出去，原油需求就會增加，根據研究機構預估，第3季全球油品平均每日需求量約9,800萬桶，幾乎回到2019年疫情發生前水準，且第4季會進一步達到9,931萬桶。
#
#
#
# 至於供給面，雖然OPEC+初步談成增產協議，從8月起每天增加40萬桶，直到12月底，也就是年底每天會增加產出200萬桶。但這個數字比起OPEC+目前減產量是每天576萬桶，產量還是比先前少。
#
#
#
# 綜合供需面來看，他認為今年油價高點會落在第3季，因為供需落差高達200萬至250萬桶，因此油價一定會往上。至於第4季，供需差縮減到120萬桶，因此油價會掉下來，但因為需求還是高於供給，所以跌幅有限。台塑化主要負責石化上游煉油及輕裂，與油價連動性強，隨國際油價居高不下，台塑化下半年營運持續看俏。台塑化董事長陳寶郎。（記者曾仁凱／攝影）facebook
# save image:
# https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/22/realtime/13101678.jpg&x=0&y=0&sw=0&sh=0&sl=W&fw=1050&exp=3600&exp=3600
# ==========
#
#
# https://money.udn.com/money/story/5617/5619316?from=edn_breaknewstab_index
# new title: 盼降級！ 調查：三級警戒影響企業營運平均5~6個月
# new content:
# 全台疫情警戒7月27日擬降回二級，但根據yes123求職網今（22）日發布的「三級警戒勞資疫外衝擊調查」發現，認為今年疫情衝擊比去年大，勞方比資方更有感，至於三級警戒影響營運，則普遍認為平均約5~6個月。此外，值得注意的是，雖然基於防疫考量，但近期覺得職場人際關係疏離感「增加」的，比例也高達60.7%。
#
#
#
# 根據yes123求職網調查顯示，相較於去年，預估「今年肺炎疫情」對台灣經濟的衝擊，結果有63.3%的勞工認為「預估今年衝擊比較大」，29.5%認為「預估兩年衝擊差不多」，僅有7.2%認為「預估去年衝擊比較大」。
#
#
#
# 相較下，觀察企業端的看法，則有50.3%的公司認為「預估兩年衝擊差不多」，41.4%認為「預估今年衝擊比較大」，也僅有8.3%認為「預估去年衝擊比較大」。
#
#
#
# 還有在防疫「三級警戒」後，上班族預估疫情對目前任職企業營運的衝擊時間，平均落在5.7個月，其中甚至有16%覺得，將長達「12個月（含）以上」。
#
#
#
# 資方也不樂觀，預估疫情對公司本身的營運衝擊，平均可能有5.2個月，其中甚至有12.1%的企業覺得，將長達「12個月（含）以上」。
#
#
#
# 解讀本次調查結果，yes123求職網發言人楊宗斌認為，相較去年，資方對今年「本土疫情」的爆發，看法偏向較為悲觀，使得加薪或徵才計畫，取消或延後的比例明顯增加。勞方也不看好待遇能提高，還要擔心輪到自己放無薪假，甚至遭裁員減薪；想靠跳槽或轉行翻身，大環境缺乏更好的工作機會，因而出現「進退兩難」的窘境。
#
#
#
# 楊宗斌也指出，雖然官方釋出不少紓困方案，但畢竟「救急不救窮」，預估景氣維持「外熱內冷」，出口接單暢旺，製造業仍缺工，有待內需產業市況復甦，相關從業人員才能安心重返工作崗位。否則處於「三級警戒」超過兩個月的生活，經濟壓力變大，加上防疫期間的人際疏離感，勞工不論在上班時或下班後，容易有職場焦慮感，對未來前（錢）途很茫然。
#
#
#
# 楊宗斌更表示，勞資雙方皆評估，需要5~6個月的時間，才能走出疫情衝擊，若由「三級警戒」開始的5月中旬往後推算，最快要到第4季業績才有望反彈。政府務必要超前佈署「振興方案」，屆時等疫情趨緩後，順勢帶動歲末企業營運績效，若獲利回溫，也讓受僱者能拿到多一點的年終獎金過個好年，彌補前三季薪酬的減損。
#
#
#
# 上述「三級警戒勞資疫外衝擊調查」是由yes123求職網於2021年7月1日到7月15日，以網路問卷進行抽樣調查，調查目前有工作的會員，會員有效問卷共1,212份，信心水準為95%，誤差值為正負2.81%。至於企業有效問卷共923份，信心水準為95%，誤差值為正負3.23%。
# save image:
# ==========
#
#
# https://money.udn.com/money/story/5621/5619304?from=edn_breaknewstab_index
# new title: 搶翻了！六都土地交易5年翻2倍 規模逼近兆元
# new content:
# 商仲業表示，資金與企業回流，帶動建商、科技產業、及壽險業積極獵地開發，統計實價資訊，六都2020年土地總交易金額多達8,426億元，已逼近兆元，相較2016年的2,957億元，成長達185%，將近二倍，也是實價登錄以來新高。
#
#
#
# 其中，台中市及桃園市已連續3年土地交易規模都超過1,000億元，桃園在2020年為六都中土地交易規模最高縣市，台中則為六都中近五年累計土地交易規模最高縣市。
#
#
#
# 信義全球資產公司總經理柯宏安分析，在重大建設成熟，交通建設逐步到位，又搭上一波台商回流下，住宅與工業的剛性需求都帶動土地交易，讓六都在2020年的土地交易規模分別都達五年內最高點。
#
#
#
# 細看各都市土地交易變化，台北市在市中心可開發土地稀少下，主要交易區域在市中心外圍，除了兵家必爭的內湖區外，南港有工業地變更開發、以及北投士林則有新興區，都已成為交易熱區。
#
#
#
# 新北市受三環六線帶動人口移動，牽動了建商購地策略，近五年交易規模穩定成長，以新莊為交易規模最大，開發商除了積極開發住宅外，也有許多企業購地興建總部，另外新店、林口、三重因有許多新興重劃區，也是交易熱區。
#
#
#
# 桃園市除了工業土地需求外，隨著機捷通車串連起北北桃生活圈，人口外移帶來的居住需求也讓土地交易明顯增加，從2018年開始突破1,000億元，2020年更來到2,357億元，為六都最高，較2016年成長277%。
#
#
#
# 近五年桃園市以中壢區交易規模最大，主要受惠於桃園高鐵特定區熱度，吸引包括國泰人壽、興富發、宏普、亞昕、皇普等建商進場，而在桃園區、龜山區的指標性重劃區也可觀察到建商以高價搶地的實力不斷浮現，成為近年重要布局戰場。
#
#
#
# 台中市因有許多技術領先的產業鏈布局、加上近年早期外移產業逐步回流、以及大型企業看好消費力跨區布局下，強勁剛性需求使其成為近年一線建商卡位重點，累計自2016年至目前已揭露交易規模達7,196億更為六都中最高。
#
#
#
# 交易熱區則以西屯區最多，該區交易金額從2016年76億元一路飆升至2020年的699億元，成長幅度驚人，更有不少北部建商南下與在地建商競爭商機，其中像興富發從2016年來已在七期重劃區投資277億元。
#
#
#
# 至於南台灣部分，科技大廠南移進駐帶動產業發展，持續帶動台南及高雄土地熱度，其中台南市近五年工業土地交易規模已佔其所有土地交易規模近25%，一直有穩定的工業地交易需求，而近二年非工業土地在就業人口帶來的居住商機下也明顯增溫。示意圖  記者游智文／攝影facebook資料來源／實價資料facebook
# save image:
# https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/22/realtime/13101659.jpg&x=0&y=0&sw=0&sh=0&sl=W&fw=1050&exp=3600&exp=3600
# https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/07/22/realtime/13101660.png&x=0&y=0&sw=0&sh=0&sl=W&fw=1050&exp=3600&exp=3600
# ==========
